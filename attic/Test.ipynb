# %%
from UnitTest import *
# Out:
# Business2018_calc
# could not find Ass_W_Anteil_komm_NWG
# could not find Fact_B_P_ratio_fec_to_area_2020
# could not find Ass_W_Anteil_komm_NWG
# could not find Ass_W_Anteil_komm_NWG
# could not find Fact_B_P_ratio_fec_to_area_2020
# Residence2018_calc
# Industry2018_calc
# Transport2018_calc
# Fuels2018_calc
# Electricity2018_calc
# could not find Ass_E_S_pv_roof_investcosts
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find Ass_E_S_pv_roof_investcosts
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# Heat2018_calc
# Lulucf2018_calc
# 12388089.72
# could not find Fact_L_G_wood_CO2e_per_ha_2018
# Agri2018_calc
# could not find In_A_soil_ratio_CO2e_to_ha
# could not find In_A_mass_calcit
# could not find In_A_mass_dolomite
# ...

# %% [raw]
# Parameters set_excel function in UnitTest:
#
#     first value: path to json with Excel values
#
#
# Parameters check function in UnitTest:
#
#     first value: sector to test i.e. 'e18'
#
#     second value integer:
#     1:  rows or cols that are not declared
#     2:  variables that are not calculated (= None)
#     4:  variables that are calculated but different to Excel value
#     8:  variables that do not differ from excel values
#     16: calculated but value not in Excel
#
#     examples: parameter 6 = 4+2 lists categories 2 and 4
#               parameter 31 lists all categegories

# %%
ut = UnitTest()
ut.set_excel('/Users/anja/Desktop/g2p/Excel_DG_values.json')
ut.check('i18', 4)
# Out:
# columns or rows not declared: 2
# values not calculated: 0
# values wrong: 0
# values not in Excel: 0
# values correct: 172
# sum: 174
# ({'g': {'energy': None,
#    'pct_energy': None,
#    'prod_volume': None,
#    'energy_use_factor': None,
#    'CO2e_pb': None,
#    'CO2e_pb_per_MWh': None,
#    'CO2e_pb_per_t': None,
#    'CO2e_cb': None,
#    'CO2e_cb_per_MWh': None,
#    'CO2e_cb_per_t': None,
#    'CO2e_total': None},
#   'p': {'energy': 722440277.7777778,
#    'pct_energy': None,
#    'prod_volume': 249861449.00000006,
#    'energy_use_factor': None,
#    'CO2e_pb': 64722608.000000015,
#    'CO2e_pb_per_MWh': None,
#    'CO2e_pb_per_t': None,
#    'CO2e_cb': 90944515.00000001,
#    'CO2e_cb_per_MWh': None,
#    'CO2e_cb_per_t': None,
#    'CO2e_total': 155667123.00000003},
#   'p_miner': {'energy': 79778055.55555557,
#    'pct_energy': None,
#    'prod_volume': 54890900.00000001,
#    'energy_use_factor': None,
#    'CO2e_pb': 19561057.000000004,
# ...

# %% [raw]
# space to test entry/fact/ass testing

# %%
g = Generator()
# Out:
# Business2018_calc
# could not find Ass_W_Anteil_komm_NWG
# could not find Fact_B_P_ratio_fec_to_area_2020
# could not find Ass_W_Anteil_komm_NWG
# could not find Ass_W_Anteil_komm_NWG
# could not find Fact_B_P_ratio_fec_to_area_2020
# Residence2018_calc
# Industry2018_calc
# Transport2018_calc
# Fuels2018_calc
# Electricity2018_calc
# could not find Ass_E_S_pv_roof_investcosts
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find Ass_E_S_pv_roof_investcosts
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# could not find In_E_full_load_h_PV
# Heat2018_calc
# Lulucf2018_calc
# 12388089.72
# could not find Fact_L_G_wood_CO2e_per_ha_2018
# Agri2018_calc
# could not find In_A_soil_ratio_CO2e_to_ha
# could not find In_A_mass_calcit
# could not find In_A_mass_dolomite
# ...

# %%
g.i18.p_miner
# Out:
# IColVars(energy=79778055.55555557, pct_energy=None, prod_volume=54890900.00000001, energy_use_factor=None, CO2e_pb=19561057.000000004, CO2e_pb_per_MWh=None, CO2e_pb_per_t=None, CO2e_cb=13847540.000000004, CO2e_cb_per_MWh=None, CO2e_cb_per_t=None, CO2e_total=33408597.000000007)
