# %% [markdown]
# # Laden der Datentabellen und deren Suchfunktionen

# %%
from setup import *

# %% [markdown]
# Es gibt 5 Datentabellen:
# * Fakten: <span class="mark">facts</span>
# * Annahmen: <span class="mark">assumptions</span>
# * Kommunenspezifische Daten: <span class="mark">rowCom</span>
# * Landkreisdaten: <span class="mark">rowK</span>
# * Bundesländerdaten: <span class="mark">rowBL</span>
#
# Auf die Daten könnt ihr mittels folgender Funktionen zugreifen:
# * fact()
# * ass()
# * valCom()
# * valK()
# * valBL()

# %%
#fact('Fact_A_S_biomass_fec_2018')
#display(facts)
#display(assumptions)
#display(rowK)
#display(rowBL)
#display(rowCom)

# %% [markdown]
# # Template für die Sektor-Variablen (Excel-Spaltennamen)

# %%
#  Definition der relevanten Spaltennamen für den Sektor T (18)
@dataclass
class TColVars: 
    
    energy:float = None
    mileage:float = None
    transport_capacity_pkm:float = None
    transport_capacity_tkm:float = None
    demand_petrol:float = None
    demand_jetfuel:float = None
    demand_diesel:float = None
    demand_fueloil:float = None
    demand_lpg:float = None
    demand_gas:float = None
    demand_biogas:float = None
    demand_bioethanol:float = None
    demand_biodiesel:float = None
    demand_electricity:float = None
    CO2e_cb:float = None


    def _get(self,i):
        
        if i == 0:
            val= self.energy
        elif i == 1:
            val= self.mileage
        elif i == 2:
            val= self.transport_capacity_pkm
        elif i == 3:
            val= self.transport_capacity_tkm
        elif i == 4:
            val= self.demand_petrol
        elif i == 5:
            val= self.demand_jetfuel
        elif i == 6:
            val= self.demand_diesel
        elif i == 7:
            val= self.demand_fueloil
        elif i == 8:
            val= self.demand_lpg
        elif i == 9:
            val= self.demand_gas
        elif i == 10:
            val= self.demand_biogas
        elif i == 11:
            val= self.demand_bioethanol
        elif i == 12:
            val= self.demand_biodiesel
        elif i == 13:
            val= self.demand_electricity
        elif i == 14:
            val= self.CO2e_cb
                
        if val == None:
            return 0
        else: 
            return val
    
    def _set(self,i,val):
        if i == 0:
            self.energy = val
        elif i == 1:
            self.mileage = val
        elif i == 2:
            self.transport_capacity_pkm = val
        elif i == 3:
            self.transport_capacity_tkm = val
        elif i == 4:
            self.demand_petrol = val
        elif i == 5:
            self.demand_jetfuel = val
        elif i == 6:
            self.demand_diesel = val
        elif i == 7:
            self.demand_fueloil = val
        elif i == 8:
            self.demand_lpg = val
        elif i == 9:
            self.demand_gas = val
        elif i == 10:
            self.demand_biogas = val
        elif i == 11:
            self.demand_bioethanol = val
        elif i == 12:
            self.demand_biodiesel = val
        elif i == 13:
            self.demand_electricity = val
        elif i == 14:
            self.CO2e_cb = val

# %%
@dataclass
class T18:
    air_inter: TColVars = TColVars()
    air_dmstc: TColVars = TColVars()
    car_it_ot: TColVars = TColVars()
    car_ab: TColVars = TColVars()
    bus: TColVars = TColVars()
    ldt_it_ot: TColVars = TColVars()
    ldt_ab: TColVars = TColVars()
    mhd_it_ot: TColVars = TColVars()
    mhd_ab: TColVars = TColVars()
    rail_ppl: TColVars = TColVars()
    metro: TColVars = TColVars()
    rail_gds: TColVars = TColVars()
    ship_dmstc: TColVars = TColVars()
    ship_inter: TColVars = TColVars()
    foot: TColVars = TColVars()
    cycl: TColVars = TColVars()
        
    #übergeordnete Zeilen
    air: TColVars = TColVars()
    street: TColVars = TColVars()
    rail: TColVars = TColVars()
    ship: TColVars = TColVars()
    others: TColVars = TColVars()
        
    #Bereitstellung (Energieträgersummen)
    s: TColVars = TColVars()
    s_petrol: TColVars = TColVars()
    s_jetfuel: TColVars = TColVars()
    s_diesel: TColVars = TColVars()
    s_fueloil: TColVars = TColVars()
    s_lpg: TColVars = TColVars()
    s_gas: TColVars = TColVars()
    s_biogas: TColVars = TColVars()
    s_bioethanol: TColVars = TColVars()
    s_biodiesel: TColVars = TColVars()
    s_elec: TColVars = TColVars()
    s_hydrogen: TColVars = TColVars()
    s_emathan: TColVars = TColVars()
    
    # erzeuge dictionry
    def dict(self):
        return asdict(self)

# %% [markdown]
# # Berechnungsfunktion Transport 2018

# %%
# Berechnungsfunktion Transport 2018

@dataclass
class Transport2018_calc(root): 
    try:
        t= root.t18       
    # res 61.700.000.000 Pers km 
        t.air_inter.transport_capacity_pkm =  (
            fact("Fact_T_D_Air_nat_trnsprt_ppl_2019")
            *entry("In_M_population_com_2018")
            /entry("In_M_population_com_203X")   
        )
         # res 1.507.745.000 t km 
        t.air_inter.transport_capacity_tkm =(
            fact("Fact_T_D_Air_dmstc_nat_trnsprt_gds_2019")
            *fact("Fact_T_D_Air_inter_nat_ratio_2018")
            *entry("In_M_population_com_2018")
            /entry("In_M_population_com_203X") 
        )
       
        # res 113.722.222 MWh 
        t.air_inter.demand_jetfuel = (
            fact("Fact_T_S_Air_nat_EB_inter_2018")
            *entry("In_M_population_com_2018") 
            /entry("In_M_population_com_203X") 
        )   
       
        # res 30.020.293  t/a
        t.air_inter.CO2e_cb =  (
            t.air_inter.demand_jetfuel
            *fact("Fact_T_S_jetfuel_EmFa_tank_wheel_2018")  # Todo: In der Excel werden   Emissionen durch Benzinverbrauch im nationalen Flugverkehr addiert: Prüfen (Ergebnis weicht daher ab) 
        )  
        # res 113.722.222 MWh
        t.air_inter.energy = t.air_inter.demand_jetfuel
        
        #-------------------
        
        # res 10.100.000.000 Pers km
        t.air_dmstc.transport_capacity_pkm = (
            fact("Fact_T_D_Air_dmstc_nat_trnsprt_ppl_2019")
            *entry("In_M_population_com_2018")
            /entry("In_M_population_com_203X")  
        )
       
        # res 79.355.000 t km
        t.air_dmstc.transport_capacity_tkm= (
            fact("Fact_T_D_Air_dmstc_nat_trnsprt_gds_2019")
            *fact("Fact_T_D_Air_dmstc_nat_ratio_2018")
            *entry("In_M_population_com_2018")
            /entry("In_M_population_com_203X") 
        )
      
        # res 108.056 MWh 
        t.air_dmstc.demand_petrol= (
            fact("Fact_T_S_Air_petrol_fec_2018")
            *entry("In_M_population_com_2018")
            /entry("In_M_population_com_203X") 
        )
       
        # res 7.805.556 MWh
        t.air_dmstc.demand_jetfuel = (
            fact("Fact_T_S_Air_nat_EB_dmstc_2018")
            *entry("In_M_population_com_2018")
            /entry("In_M_population_com_203X") 
        )
       
        # res 2.085.724  t/a
        t.air_dmstc.CO2e_cb =  (
            t.air_dmstc.demand_jetfuel
            *fact("Fact_T_S_jetfuel_EmFa_tank_wheel_2018")
            + t.air_dmstc.demand_petrol
            *fact("Fact_T_S_petroljet_EmFa_tank_wheel_2018")
        )
      
        # res 7.913.611 MWh 
        t.air_dmstc.energy = t.air_dmstc.demand_jetfuel + t.air_dmstc.demand_petrol    
        
        #-----------------------
        # res 456.061.500.000 Fz km
        t.car_it_ot.mileage = (
            entry("In_T_mil_car_it_at") 
        )
        
        # res 657.704.211.506 Pers km 
        t.car_it_ot.transport_capacity_pkm = (
            t.car_it_ot.mileage
            *fact("Fact_T_D_lf_ppl_Car_2018")  
        )
        
        # res 140.583.679 MWh
        t.car_it_ot.demand_petrol=(
            t.car_it_ot.mileage
            *fact("Fact_T_S_Car_frac_petrol_with_phev_mlg_2018") 
            *(1-fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018"))
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018") 
        )
            
        # res 137.907.651 MWh
        t.car_it_ot.demand_diesel= (
           t.car_it_ot.mileage
           *fact("Fact_T_S_Car_frac_diesel_mlg_2018")
           *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
           *fact("Fact_T_S_Car_SEC_diesel_it_at_2018")
        )
        
        #res 3.211.348 MWh
        t.car_it_ot.demand_lpg= (
            t.car_it_ot.mileage
            *fact("Fact_T_S_Car_frac_lpg_mlg_2018")
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018")
        )
        
        # res 550.841 MWh
        t.car_it_ot.demand_gas= (
           t.car_it_ot.mileage
            *fact("Fact_T_S_Car_frac_cng_mlg_2018")
            *(1-fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018"))
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018")
        )
    
       # res 129.210 MWh
        t.car_it_ot.demand_biogas=(
            t.car_it_ot.mileage
            *fact("Fact_T_S_Car_frac_cng_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018")
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018")
        )
    
  
    
        #res  6.316.717 MWh
        t.car_it_ot.demand_bioethanol= (
            t.car_it_ot.mileage
            *fact("Fact_T_S_Car_frac_petrol_with_phev_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018")
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018")            
        )

    
        
        
        # res 8.026.371 MWh  
        t.car_it_ot.demand_biodiesel = (
            t.car_it_ot.mileage
            *fact("Fact_T_S_Car_frac_diesel_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_Car_SEC_diesel_it_at_2018")
        )


        # res 121.985 MWh
        t.car_it_ot.demand_electricity = (
            t.car_it_ot.mileage
            *("Fact_T_S_Car_frac_bev_with_phev_mlg_2018")
            *("Fact_T_S_Car_SEC_elec_it_at_2018")
        )
    
        # res  75.732.141 t/a 
        
        t.car_it_ot.CO2e_cb =(
            t.car_it_ot.demand_petrol
            *fact("Fact_T_S_petrol_EmFa_tank_wheel_2018")
            +t.car_it_ot.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.car_it_ot.demand_lpg
            *("Fact_T_S_lpg_EmFa_tank_wheel_2018")
            +t.car_it_ot.demand_gas
            *("Fact_T_S_cng_EmFa_tank_wheel_2018")
       
        )
    

        # res 296.847.801 MWh
        t.car_it_ot.energy= (
            t.car_it_ot.demand_petrol
            +t.car_it_ot.demand_diesel
            +t.car_it_ot.demand_lpg
            +t.car_it_ot.demand_gas
            +t.car_it_ot.demand_biogas
            +t.car_it_ot.demand_bioethanol
            +t.car_it_ot.demand_biodiesel
            +t.car_it_ot.demand_electricity
        )
        
        #--------------------
        
        # res 200.879.200.000 Fz km
        t.car_ab.mileage = (
            entry("In_T_mil_car_ab") 
        )
        
        # res 289.695.788.494 Pers km
        t.car_ab.transport_capacity_pkm = (
            t.car_ab.mileage
            *fact("Fact_T_D_lf_ppl_Car_2018")  
        )
        
        # res 71.637.731 MWh
        t.car_ab.demand_petrol=(
            t.car_ab.mileage
            *fact("Fact_T_S_Car_frac_petrol_with_phev_mlg_2018") 
            *(1-fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018"))
            *fact("Fact_T_S_Car_SEC_petrol_ab_2018") 
        )
            
        # res 68.266.402 MWh
        t.car_ab.demand_diesel= (
           t.car_ab.mileage
           *fact("Fact_T_S_Car_frac_diesel_mlg_2018")
           *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
           *fact("Fact_T_S_Car_SEC_diesel_ab_2018")
        )
        
        #res 1.636.418 MWh
        t.car_ab.demand_lpg= (
            t.car_ab.mileage
            *fact("Fact_T_S_Car_frac_lpg_mlg_2018")
            *fact("Fact_T_S_Car_SEC_petrol_ab_2018")
        )
        
        # res 242.626 MWh
        t.car_ab.demand_gas= (
           t.car_ab.mileage
            *fact("Fact_T_S_Car_frac_cng_mlg_2018")
            *(1-fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018"))
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018") #Todo Prüfen warum hier ...SEC_petrol_it_at verwendet wird und nicht ...SEC_petrol_ab 
        )
    
       # res 56.912 MWh
        t.car_ab.demand_biogas=(
            t.car_ab.mileage
            *fact("Fact_T_S_Car_frac_cng_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018")
            *fact("Fact_T_S_Car_SEC_petrol_it_at_2018") #Todo Prüfen warum hier ...SEC_petrol_it_at verwendet wird und nicht ...SEC_petrol_ab 
        )
    
  
    
        #res  3.218.832 MWh
        t.car_ab.demand_bioethanol= (
            t.car_ab.mileage
            *fact("Fact_T_S_Car_frac_petrol_with_phev_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018")
            *fact("Fact_T_S_Car_SEC_petrol_ab_2018")            
        )

    
        
        
        # res 3.973.177 MWh 
        t.car_ab.demand_biodiesel = (
            t.car_ab.mileage
            *fact("Fact_T_S_Car_frac_diesel_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_Car_SEC_diesel_ab_2018")
        )


        # res 85.897 MWh
        t.car_ab.demand_electricity = (
            t.car_ab.mileage
            *("Fact_T_S_Car_frac_bev_with_phev_mlg_2018")
            *("Fact_T_S_Car_SEC_elec_ab_2018")
        )
    
        # 38.048.389 t/a
        t.car_ab.CO2e_cb =(
            t.car_ab.demand_petrol
            *fact("Fact_T_S_petrol_EmFa_tank_wheel_2018")
            +t.car_ab.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.car_ab.demand_lpg
            *("Fact_T_S_lpg_EmFa_tank_wheel_2018")
            +t.car_ab.demand_gas
            *("Fact_T_S_cng_EmFa_tank_wheel_2018")

        )
    

        # res 149.117.995 MWh
        t.car_ab.energy= (
            t.car_ab.demand_petrol
            +t.car_ab.demand_diesel
            +t.car_ab.demand_lpg
            +t.car_ab.demand_gas
            +t.car_ab.demand_biogas
            +t.car_ab.demand_bioethanol
            +t.car_ab.demand_biodiesel
            +t.car_ab.demand_electricity
        )
        
        #----------------
        
        # res 2.343.000.000 Fz km
        t.bus.mileage=(
            entry("In_T_mil_bus") 
        )
        
        # res 35.594.900.435 Pers km
        t.bus.transport_capacity_pkm=(
            t.bus.mileage
            *fact("Fact_T_D_lf_ppl_Bus_2018")  
        )
        
        
        #res 8.426.134 MWh
        t.bus.demand_diesel= (
           t.bus.mileage
           *fact("Fact_T_S_Bus_frac_diesel_with_hybrid_stock_2018")
           *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
           *fact("Fact_T_S_Bus_SEC_diesel_2018")
        )
       
        # res 162.136 MWh
        t.bus.demand_gas = (
            t.bus.mileage
            *fact("Fact_T_S_Bus_frac_cng_stock_2018")
            *(1-fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018"))
            *fact("Fact_T_S_Bus_SEC_diesel_2018")
        )
        
        # res 38.032 MWh
        t.bus.demand_biogas= (
            t.bus.mileage
            *("factFact_T_S_Bus_frac_cng_stock_2018")
            *fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018")
            *fact("Fact_T_S_Bus_SEC_diesel_2018")
        )
        
        # res 485.406 MWh
        t.bus.demand_biodiesel=(
            t.bus.mileage
            *fact("Fact_T_S_Bus_frac_diesel_stock_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_Bus_SEC_diesel_2018")
            ) 
          
        # res 13.854 MWh
        t.bus.demand_electricity=(
            t.bus.mileage
            *fact("Fact_T_S_Bus_frac_bev_stock_2018")
            *fact("Fact_T_S_Bus_SEC_elec_2018")
        ) 
        
        
           # 2.278.190 t/a

        t.bus.CO2e_cb =(
            +t.bus.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.bus.demand_lpg
            *("Fact_T_S_lpg_EmFa_tank_wheel_2018")
            +t.bus.demand_gas
            *("Fact_T_S_cng_EmFa_tank_wheel_2018")
 
        )
    

        # res 9.125.561 MWh
        t.bus.energy= (
            +t.bus.demand_diesel
            +t.bus.demand_gas
            +t.bus.demand_biogas
            +t.bus.demand_biodiesel
            +t.bus.demand_electricity
        )
        
        #---------------------
        
        # res 36.749.000.000 Fz km
        t.ldt_it_ot.mileage = (
            entry("In_T_mil_ldt_it_at") 
        )

       # 5.516.114.569 t km
        t.ldt_it_ot.transport_capacity_tkm= (
            t.ldt_it_ot.mileage
            *fact("Fact_T_D_lf_gds_LDT_2018")
        )
        
        #863.649 MWh 
        t.ldt_it_ot.demand_petrol=(
        t.ldt_it_ot.mileage
        *fact("Fact_T_S_LDT_frac_petrol_mlg_2018")
        *(1-fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018"))
        *fact("Fact_T_S_LDT_SEC_petrol_it_at_2018")
        )
        
        # 30.129.512 MWh   
        t.ldt_it_ot.demand_diesel= (
            t.ldt_it_ot.mileage
            *fact("Fact_T_S_LDT_frac_diesel_mlg_2018")
            *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
            *fact("Fact_T_S_LDT_SEC_diesel_it_at_2018")
        ) 

         # 127.848 MWh   
        t.ldt_it_ot.demand_lpg=(
            t.ldt_it_ot.mileage
            *fact("Fact_T_S_LDT_frac_lpg_mlg_2018")
            *fact("Fact_T_S_LDT_SEC_petrol_it_at_2018")
        )

    
        #38.806 MWh
        t.ldt_it_ot.demand_bioethanol=(
            t.ldt_it_ot.mileage
            *fact("Fact_T_S_LDT_frac_petrol_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018")
            *fact("Fact_T_S_LDT_SEC_petrol_it_at_2018")
        )

        #1.753.569 MWh
        t.ldt_it_ot.demand_biodiesel=(
            t.ldt_it_ot.mileage
            *fact("Fact_T_S_LDT_frac_diesel_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_LDT_SEC_diesel_it_at_2018")
        )

        #29.887 MWh
        t.ldt_it_ot.demand_electricity=(
            t.ldt_it_ot.mileage
            *fact("Fact_T_S_LDT_frac_bev_mlg_2018")
            *fact("Fact_T_S_LDT_SEC_elec_it_at_2018")
        )
            
     #8.294.035 t/a       
        t.ldt_it_ot.CO2e_cb =(
            t.ldt_it_ot.demand_petrol
            *fact("Fact_T_S_petrol_EmFa_tank_wheel_2018")
            +t.ldt_it_ot.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.ldt_it_ot.demand_lpg
            *("Fact_T_S_lpg_EmFa_tank_wheel_2018")
 
        )
        
        # 32.943.271 MWh
        t.ldt_it_ot.energy= (
            t.ldt_it_ot.demand_petrol
            +t.ldt_it_ot.demand_diesel
            +t.ldt_it_ot.demand_lpg
            +t.ldt_it_ot.demand_bioethanol
            +t.ldt_it_ot.demand_biodiesel
            +t.ldt_it_ot.demand_electricity
        )
        
        #-------------------------
        
        # 14.549.300.000 Fz km
        t.ldt_ab.mileage = (
            entry("In_T_mil_ldt_ab") 
        )
                
        # 2.183.885.431 t km
        t.ldt_ab.transport_capacity_tkm= (
            t.ldt_ab.mileage
            *fact("Fact_T_D_lf_gds_LDT_2018")
        )
        
        # 443.472 MWh 
        t.ldt_ab.demand_petrol=(
        t.ldt_ab.mileage
        *fact("Fact_T_S_LDT_frac_petrol_mlg_2018")
        *(1-fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018"))
        *fact("Fact_T_S_LDT_SEC_petrol_ab_2018")
        )
        
        # 16.610.550 MWh   
        t.ldt_ab.demand_diesel= (
            t.ldt_ab.mileage
            *fact("Fact_T_S_LDT_frac_diesel_mlg_2018")
            *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
            *fact("Fact_T_S_LDT_SEC_diesel_ab_2018")
        ) 

         # 65.648 MWh  
        t.ldt_ab.demand_lpg=(
            t.ldt_ab.mileage
            *fact("Fact_T_S_LDT_frac_lpg_mlg_2018")
            *fact("Fact_T_S_LDT_SEC_petrol_ab_2018")
        )

    
        #19.926 MWh 
        t.ldt_ab.demand_bioethanol=(
            t.ldt_ab.mileage
            *fact("Fact_T_S_LDT_frac_petrol_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_benzin_bio_frac_2018")
            *fact("Fact_T_S_LDT_SEC_petrol_ab_2018")
        )

        # 966.752 MWh
        t.ldt_ab.demand_biodiesel=(
            t.ldt_ab.mileage
            *fact("Fact_T_S_LDT_frac_diesel_mlg_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_LDT_SEC_diesel_ab_2018")
        )

        # 20.475 MWh
        t.ldt_ab.demand_electricity=(
            t.ldt_ab.mileage
            *fact("Fact_T_S_LDT_frac_bev_mlg_2018")
            *fact("Fact_T_S_LDT_SEC_elec_ab_2018")
        )
            
        #4.562.536 t/a
      
        t.ldt_ab.CO2e_cb =(
            t.ldt_ab.demand_petrol
            *fact("Fact_T_S_petrol_EmFa_tank_wheel_2018")
            +t.ldt_ab.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.ldt_ab.demand_lpg
            *("Fact_T_S_lpg_EmFa_tank_wheel_2018")

        )
        
        
        # 18.126.823 MWh
        t.ldt_ab.energy= (
            t.ldt_ab.demand_petrol
            +t.ldt_ab.demand_diesel
            +t.ldt_ab.demand_lpg
            +t.ldt_ab.demand_bioethanol
            +t.ldt_ab.demand_biodiesel
            +t.ldt_ab.demand_electricity
        )
        
        #-----------------------
        
        # 28.430.600.000 Fz km
        t.mhd_it_ot.mileage = (
            entry("In_T_mil_mhd_it_at") 
        )
        
        #212.745.261.612 t km
        t.mhd_it_ot.transport_capacity_tkm= (
            t.mhd_it_ot.mileage
            *fact("Fact_T_D_lf_gds_MHD_2018")
        )
        
        # 75.928.091 MWh
        t.mhd_it_ot.demand_diesel=(
            t.mhd_it_ot.mileage
            *fact("Fact_T_S_MHD_frac_diesel_stock_2018")
            *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
            *fact("Fact_T_S_MHD_SEC_diesel_it_at_2018")
        )
        
        #58.690 MWh
        t.mhd_it_ot.demand_gas=(
            t.mhd_it_ot.mileage
            *fact("Fact_T_S_MHD_frac_cng_lngl_stock_2018")
            *fact(1-("Fact_T_S_Rl_Rd_cng_bio_frac_2018"))
            *fact("Fact_T_S_MHD_SEC_diesel_it_at_2018")
            )
        
        # 13.767 MWh 
        t.mhd_it_ot.demand_biogas=(
            t.mhd_it_ot.mileage
            *fact("Fact_T_S_MHD_frac_cng_lngl_stock_2018")
            *fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018")
            *fact("Fact_T_S_MHD_SEC_diesel_it_at_2018")
        )
        
        # 4.419.095 MWh
        t.mhd_it_ot.demand_biodiesel= (
            t.mhd_it_ot.mileage
            *fact("Fact_T_S_MHD_frac_diesel_stock_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_MHD_SEC_diesel_it_at_2018")
        )

        # 13.271 MWh    
        t.mhd_it_ot.demand_electricity=(
            t.mhd_it_ot.mileage
            *fact("Fact_T_S_MHD_frac_bev_stock_2018")
            *fact("Fact_T_S_MHD_SEC_elec_it_at_2018")
        )
            
          # 20.246.442 t/a

        t.mhd_it_ot.CO2e_cb=( 
            t.mhd_it_ot.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.mhd_it_ot.demand_gas
            *("Fact_T_S_cng_EmFa_tank_wheel_2018")

        )    
        
        
        
        # 80.432.915 MWh
        t.mhd_it_ot.energy=(
            t.mhd_it_ot.demand_diesel
            +t.mhd_it_ot.demand_gas
            +t.mhd_it_ot.demand_biogas
            +t.mhd_it_ot.demand_biodiesel
            +t.mhd_it_ot.demand_electricity
        )
        
        #--------------
        
        # 35.937.900.000 Fz km
        t.mhd_ab.mileage = (
            entry("In_T_mil_mhd_ab") 
        )
        
        #268.922.145.057 t km
        t.mhd_ab.transport_capacity_tkm= (
            t.mhd_ab.mileage
            *fact("Fact_T_D_lf_gds_MHD_2018")
        )
        
        # 98.546.344 MWh
        t.mhd_ab.demand_diesel=(
            t.mhd_ab.mileage
            *fact("Fact_T_S_MHD_frac_diesel_stock_2018")
            *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
            *fact("Fact_T_S_MHD_SEC_diesel_ab_2018")
        )
        
        # 76.174 MWh
        t.mhd_ab.demand_gas=(
            t.mhd_ab.mileage
            *fact("Fact_T_S_MHD_frac_cng_lngl_stock_2018")
            *fact(1-("Fact_T_S_Rl_Rd_cng_bio_frac_2018"))
            *fact("Fact_T_S_MHD_SEC_diesel_ab_2018")
            )
        
        # 17.868 MWh
        t.mhd_ab.demand_biogas=(
            t.mhd_ab.mileage
            *fact("Fact_T_S_MHD_frac_cng_lngl_stock_2018")
            *fact("Fact_T_S_Rl_Rd_cng_bio_frac_2018")
            *fact("Fact_T_S_MHD_SEC_diesel_it_at_2018")
        )
        
        # 5.735.502 MWh
        t.mhd_ab.demand_biodiesel= (
            t.mhd_ab.mileage
            *fact("Fact_T_S_MHD_frac_diesel_stock_2018")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
            *fact("Fact_T_S_MHD_SEC_diesel_ab_2018")
        )

        # 23.251 MWh    
        t.mhd_ab.demand_electricity=(
            t.mhd_ab.mileage
            *fact("Fact_T_S_MHD_frac_bev_stock_2018")
            *fact("Fact_T_S_MHD_SEC_elec_ab_2018")
        )
            
          # 26.277.664 t/a
        t.mhd_ab.CO2e_cb=( 
            t.mhd_ab.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
            +t.mhd_ab.demand_gas
            *("Fact_T_S_cng_EmFa_tank_wheel_2018")

        )    
        
                
        
        # 104.399.138 MWh
        t.mhd_ab.energy= (
            t.mhd_ab.demand_diesel
            +t.mhd_ab.demand_gas
            +t.mhd_ab.demand_biogas
            +t.mhd_ab.demand_biodiesel
            +t.mhd_ab.demand_electricity
        )
        
        #-----------------
        
        # 6.297.810 MWh 
        t.rail_ppl.demand_electricity =(
            entry("In_T_ec_rail_ppl_elec")
        )
        
        # 3.164.605 MWh 
        t.rail_ppl.demand_diesel=(
            entry("In_T_ec_rail_ppl_diesel")
            *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
        )
        
        # 184.183 MWh
        t.rail_ppl.demand_biodiesel=(
            entry("In_T_ec_rail_ppl_diesel")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
        )

        # 97.700.000.000 Pers km
        t.rail_ppl.transport_capacity_pkm=(
            (t.rail_ppl.demand_diesel+t.rail_ppl.demand_biodiesel)
            /("Fact_T_S_Rl_Train_ppl_long_diesel_SEC_2018")
            +t.rail_ppl.demand_electricity
            /("Fact_T_S_Rl_Train_ppl_long_elec_SEC_2018")
        )   
     
       # 843.358 t/a    
        t.rail_ppl.CO2e_cb=( 
            t.rail_ppl.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")
        )  
        
        # 9.646.598 MWh
        t.rail_ppl.energy= (
            +t.rail_ppl.demand_diesel
            +t.rail_ppl.demand_biodiesel
            +t.rail_ppl.demand_electricity
        )
        
        #--------------
        # 308.900.000 Fz km 
        t.metro.mileage = (
            entry("In_T_mil_metro") 
        )
        
        # 17.700.000.000 Pers km
        t.metro.transport_capacity_pkm=(
            t.metro.mileage
            *fact("Fact_T_D_lf_Rl_Metro_2018")
        )
        
       #  1.235.600 MWh
        t.metro.demand_electricity=(
            t.metro.mileage
            *("Fact_T_S_Rl_Metro_SEC_fzkm_2018")
        )
        
       # 1.235.600 MWh  
        t.metro.energy= (
            t.metro.demand_electricity
        )
        #--------------
        
         # 4.015.518 MWh
        t.rail_gds.demand_electricity =(
            entry("In_T_ec_rail_gds_elec")
        )
        
        # 995.430 MWh 
        t.rail_gds.demand_diesel=(
            entry("In_T_ec_rail_gds_diesel")
            *(1-fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018"))
        )
        
        # 57.935 MWh
        t.rail_gds.demand_biodiesel=(
            entry("In_T_ec_rail_gds_diesel")
            *fact("Fact_T_S_Rl_Rd_diesel_bio_frac_2018")
        )

        # 133.700.000.000 t km
        t.rail_gds.transport_capacity_tkm=(
            (t.rail_gds.demand_diesel+t.rail_gds.demand_biodiesel)
            /("Fact_T_S_Rl_Train_gds_diesel_SEC_2018")
            +t.rail_gds.demand_electricity
            /("Fact_T_S_Rl_Train_gds_elec_SEC_2018")
        )
     
       # 265.279 t/a   
        t.rail_gds.CO2e_cb=( 
            t.rail_gds.demand_diesel
            *fact("Fact_T_S_diesel_EmFa_tank_wheel_2018")

        )
        
        # 5.068.883 MWh
        t.rail_gds.energy= (
            +t.rail_gds.demand_diesel
            +t.rail_gds.demand_biodiesel
            +t.rail_gds.demand_electricity
        )
        
        #-------------
        
        # res 2.949.722 MWh
        t.ship_dmstc.transport_capacity_tkm = (
            fact('Fact_T_D_Shp_dmstc_trnsprt_gds_2018')
            * entry('In_M_population_2018')
            / entry('EW18D') # Todo -> noch keinen Namen in Tabelle
        )
        # res: 46.900.000.000 t km

        t.ship_dmstc.demand_diesel = (
            entry('In_M_population_2018')
            / entry('EW18D') # Todo -> noch keinen Namen in Tabelle
            * fact('Fact_T_S_Shp_diesel_fec_2018')
        )
        # res: 2.949.722 MWh
        t.ship_dmstc.energy = t.ship_dmstc.demand_diesel

        t.ship_dmstc.CO2e_cb = (
            t.ship_dmstc.demand_diesel
            * fact('Fact_T_S_diesel_EmFa_tank_wheel_2018')
        )
        # res: 786.093  t/a
        
        #---------------------
        
        t.ship_inter.transport_capacity_tkm = (
            fact('Fact_T_D_Shp_sea_nat_trnspt_gds_2013')
            * entry('In_M_population_2018')
            / entry('EW18D') # Todo -> noch keinen Namen in Tabelle
        )
        # res: 1.982.900.000.000 t km

        t.ship_inter.demand_fueloil = (
            entry('In_M_population_2018')
            / entry('EW18D') # Todo -> noch keinen Namen in Tabelle
            * fact('Fact_T_D_Shp_sea_nat_EC_2018')
        )
        t.ship_inter.energy = t.ship_inter.demand_fueloil
        # res: 19.722.222 MWh

        t.ship_inter.CO2e_cb = (
            t.ship_inter.demand_fueloil
            * fact('Fact_T_S_fueloil_EmFa_tank_wheel_2018')
        )
        # res: 5.396.000  t/a
        
        #------------------------
        
        if entry('In_T_rt7') in [71,72,73,74,75,76,77]:
            
            t.foot.transport_capacity_pkm = ( 
                entry('In_M_population_2018') 
                * 365 
                * fact('Fact_T_D_modal_split_foot_rt'+str(entry('In_T_rt7')))
            )
            
            t.cycl.transport_capacity_pkm = (
                entry('In_M_population_2018') 
                * 365 
                * fact('Fact_T_D_modal_split_cycl_rt'+str(entry('In_T_rt7')))
            )
            
        else:
            t.foot.transport_capacity_pkm = ( 
                entry('In_M_population_2018') 
                * 365 
                * fact('Fact_T_D_modal_split_foot_rt_nat')
            )
            
            t.cycl.transport_capacity_pkm = (
                entry('In_M_population_2018') 
                * 365 
                * fact('Fact_T_D_modal_split_cycl_rt_nat')
            )
        
        #------------------------------ Berechnung der Oberklassensummen                 
        for i in range(len([a for a in dir(TColVars) if not a.startswith("_")])):
            t.air._set(i,t.air_inter._get(i)+t.air_dmstc._get(i))
            t.street._set(i,t.car_it_ot._get(i) + t.car_ab._get(i) + t.bus._get(i) + t.ldt_it_ot._get(i) + t.ldt_ab._get(i) + t.mhd_it_ot._get(i) + t.mhd_ab._get(i))
            t.rail._set(i,t.rail_ppl._get(i) + t.metro._get(i) + t.rail_gds._get(i))
            t.ship._set(i,t.ship_dmstc._get(i) + t.ship_inter._get(i))
        
        
        #----------------------------------------------------
        t.s_petrol.energy = t.air_dmstc.demand_petrol + t.car_it_ot.demand_petrol + t.car_ab.demand_petrol + t.ldt_it_ot.demand_petrol + t.ldt_ab.demand_petrol
        t.s_jetfuel.energy = t.air_inter.demand_jetfuel+ t.air_dmstc.demand_jetfuel
        t.s_diesel.energy = t.car_it_ot.demand_diesel + t.car_ab.demand_diesel+ t.bus.demand_diesel+ t.ldt_it_ot.demand_diesel + t.ldt_ab.demand_diesel + t.mhd_it_ot.demand_diesel + t.mhd_ab.demand_diesel + t.rail_ppl.demand_diesel + t.rail_gds.demand_diesel + t.ship_dmstc.demand_diesel 
        t.s_fueloil.energy = t.ship_inter.demand_fueloil
        t.s_lpg.energy  = t.car_it_ot.demand_lpg + t.car_ab.demand_lpg + t.ldt_it_ot.demand_lpg + t.ldt_ab.demand_lpg
        t.s_gas.energy = t.car_it_ot.demand_gas + t.car_ab.demand_gas+ t.bus.demand_gas+ t.mhd_it_ot.demand_gas + t.mhd_ab.demand_gas
        t.s_biogas.energy = t.car_it_ot.demand_biogas + t.car_ab.demand_biogas+ t.bus.demand_biogas+ t.mhd_it_ot.demand_biogas + t.mhd_ab.demand_biogas
        t.s_bioethanol.energy  = t.car_it_ot.demand_bioethanol + t.car_ab.demand_bioethanol + t.ldt_it_ot.demand_bioethanol + t.ldt_ab.demand_bioethanol
        t.s_biodiesel.energy = t.car_it_ot.demand_biodiesel + t.car_ab.demand_biodiesel+ t.bus.demand_biodiesel+ t.ldt_it_ot.demand_biodiesel + t.ldt_ab.demand_biodiesel + t.mhd_it_ot.demand_biodiesel + t.mhd_ab.demand_biodiesel + t.rail_ppl.demand_biodiesel + t.rail_gds.demand_biodiesel  
        t.s_elec.energy = t.car_it_ot.demand_electricity + t.car_ab.demand_electricity+ t.bus.demand_electricity+ t.ldt_it_ot.demand_electricity + t.ldt_ab.demand_electricity + t.mhd_it_ot.demand_electricity + t.mhd_ab.demand_electricity + t.rail_ppl.demand_electricity + t.metro.demand_electricity+.rail_gds.demand_electricity
